# %% [markdown]
# # Imports & Installs

# %%
# !pip install --upgrade librosa -q
# !pip install soundfile -q

import sys
MAIN_PATH="/home/mrtn/Documents/deep-dereverb"
sys.path.append(MAIN_PATH) #Para poder importar mi archivo .py como libreria

import tensorflow as tf
import tensorflow.keras.layers as tfkl
from keras import layers, models, losses
from scipy.signal import stft, istft
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Audio
import soundfile as sf
import glob 
import os
from model.capas import Spectrogram, TranslateRange, MSE, Normalize, Normalize_pos
from model.data_loader import DataGenerator
import random
# Out:
# WARNING: You are using pip version 20.2.3; however, version 21.0.1 is available.
# You should consider upgrading via the '/home/mrtn/anaconda3/envs/tf/bin/python -m pip install --upgrade pip' command.
# WARNING: You are using pip version 20.2.3; however, version 21.0.1 is available.
# You should consider upgrading via the '/home/mrtn/anaconda3/envs/tf/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# # Traigo el training set al env de colab

# %%
#traigo el zip al env
zip_path = os.path.join(MAIN_PATH, 'data/data_ready_mask.zip')
# !cp "{zip_path}" .

#descomprimo y borro el zip
!7z x data_ready_mask.zip
# !rm data_ready_mask.zip
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 9440974470 bytes (9004 MiB)
#
# Extracting archive: data_ready_mask.zip
# --
# Path = data_ready_mask.zip
# Type = zip
# Physical Size = 9440974470
# 64-bit = +
#
# Everything is Ok
#
# Folders: 1
# Files: 9654
# Size:       10163731200
# Compressed: 9440974470

# %%
#para ver cuanto pesa la carpeta descomprimida
#!rm data_ready -r
# !du -s -h data_ready_mask
# Out:
# 9.6G	data_ready_mask

# %% [markdown]
# # Data Generator config

# %%
from model.data_loader import build_generators
params = {'dim': (257,256), 'batch_size': 16, 'shuffle': True}
training_generator, validation_generator = build_generators(MAIN_PATH, params)
# Out:
# Cantidad de datos para entrenamiento: 7723
# Cantidad de datos para validacion: 1931

# %% [markdown]
# # Armando el modelo

# %%
tf.keras.backend.clear_session()
eps = np.finfo(float).eps

audio_in = tfkl.Input((257,256), name = 'Entrada_audio')
mask_in = tfkl.Input((257,256), name = 'Entrada_mascara')

#Acondicionamiento
audio = tf.expand_dims(audio_in,axis=-1, name='expand_audio')
audio = tfkl.Cropping2D(((0,1),(0,0)), name='Crop_audio')(audio)

mask = tf.expand_dims(mask_in,axis=-1, name= 'expand_mask')
mask = tfkl.Cropping2D(((0,1),(0,0)), name = 'Crop_mask')(mask)


#ENCODER
enc = tfkl.Conv2D(64, kernel_size=(4,4), strides=2, padding='SAME', input_shape=(256,256,1), name='CONV1')(audio)
enc_1 = tfkl.LeakyReLU(alpha = 0.2, name = 'ACT1')(enc)

enc_2 = tfkl.Conv2D(128, kernel_size=(4,4), strides=2, padding='SAME', name='CONV2')(enc_1)
enc_2 = tfkl.BatchNormalization(name='BATCH2')(enc_2)
enc_2 = tfkl.LeakyReLU(alpha = 0.2, name='ACT2')(enc_2)

enc_3 = tfkl.Conv2D(256, kernel_size=(4,4), strides=2, padding='SAME', name='CONV3')(enc_2)
enc_3 = tfkl.BatchNormalization(name='BATCH3')(enc_3)
enc_3 = tfkl.LeakyReLU(alpha = 0.2, name='ACT3')(enc_3)

enc_4 = tfkl.Conv2D(512, kernel_size=(4,4), strides=2, padding='SAME', name='CONV4')(enc_3)
enc_4 = tfkl.BatchNormalization(name='BATCH4')(enc_4)
enc_4 = tfkl.LeakyReLU(alpha = 0.2, name='ACT4')(enc_4)

enc_5 = tfkl.Conv2D(512, kernel_size=(4,4), strides=2, padding='SAME', name='CONV5')(enc_4)
enc_5 = tfkl.BatchNormalization(name='BATCH5')(enc_5)
enc_5 = tfkl.LeakyReLU(alpha = 0.2, name='ACT5')(enc_5)

enc_6 = tfkl.Conv2D(512, kernel_size=(4,4), strides=2, padding='SAME', name='CONV6')(enc_5)
enc_6 = tfkl.BatchNormalization(name = 'BATCH6')(enc_6)
enc_6 = tfkl.LeakyReLU(alpha = 0.2, name='ACT6')(enc_6)

enc_7 = tfkl.Conv2D(512, kernel_size=(4,4), strides=2, padding='SAME', name='CONV7')(enc_6)
enc_7 = tfkl.BatchNormalization(name = 'BATCH7')(enc_7)
enc_7 = tfkl.LeakyReLU(alpha = 0.2, name='ACT7')(enc_7)

enc_8 = tfkl.Conv2D(512, kernel_size=(4,4), strides=2, padding='SAME', name='CONV8')(enc_7)
enc_8 = tfkl.BatchNormalization(name = 'BATCH8')(enc_8)
enc_8 = tfkl.ReLU()(enc_8)


#DECODER
dec = tfkl.UpSampling2D(size=(2,2), interpolation = 'nearest')(enc_8)
dec = tfkl.Conv2D(512, kernel_size=(4,4), strides=1, padding='SAME', name='CONV9')(dec)
#dec = tfkl.Conv2DTranspose(256, kernel_size=(4,4), strides=2, padding='SAME', name='CONV9')(enc_8)
dec = tfkl.BatchNormalization(name = 'BATCH9')(dec)
dec = tfkl.Dropout(rate = 0.5)(dec)
dec = tfkl.ReLU()(dec)
dec = tfkl.Concatenate(axis=-1)([dec, enc_7])

dec = tfkl.UpSampling2D(size=(2,2), interpolation = 'nearest')(dec)
dec = tfkl.Conv2D(512, kernel_size=(4,4), strides=1, padding='SAME', name='CONV10')(dec)
#dec = tfkl.Conv2DTranspose(256, kernel_size=(4,4), strides=2, padding='SAME', name='CONV10')(dec)
dec = tfkl.BatchNormalization(name = 'BATCH10')(dec)
dec = tfkl.Dropout(rate = 0.5)(dec)
dec = tfkl.ReLU()(dec)
dec = tfkl.Concatenate(axis=-1)([dec, enc_6])

dec = tfkl.UpSampling2D(size=(2,2), interpolation = 'nearest')(dec)
dec = tfkl.Conv2D(512, kernel_size=(4,4), strides=1, padding='SAME', name='CONV11')(dec)
#dec = tfkl.Conv2DTranspose(256, kernel_size=(4,4), strides=2, padding='SAME', name='CONV11')(dec)
dec = tfkl.BatchNormalization(name = 'BATCH11')(dec)
dec = tfkl.Dropout(rate = 0.5)(dec)
dec = tfkl.ReLU()(dec)
dec = tfkl.Concatenate(axis=-1)([dec, enc_5])

dec = tfkl.UpSampling2D(size=(2,2), interpolation = 'nearest')(dec)
dec = tfkl.Conv2D(512, kernel_size=(4,4), strides=1, padding='SAME', name='CONV12')(dec)
#dec = tfkl.Conv2DTranspose(256, kernel_size=(4,4), strides=2, padding='SAME', name='CONV12')(dec)
dec = tfkl.BatchNormalization(name = 'BATCH12')(dec)
dec = tfkl.ReLU()(dec)
dec = tfkl.Concatenate(axis=-1)([dec, enc_4])

dec = tfkl.UpSampling2D(size=(2,2), interpolation = 'nearest')(dec) #PROVISORIO
dec = tfkl.Conv2D(256, kernel_size=(4,4), strides=1, padding='SAME', name='CONV13')(dec)
#dec = tfkl.Conv2DTranspose(128, kernel_size=(4,4), strides=2, padding='SAME', name='CONV13')(dec)
dec = tfkl.BatchNormalization(name = 'BATCH13')(dec)
dec = tfkl.ReLU()(dec)
dec = tfkl.Concatenate(axis=-1)([dec, enc_3])

dec = tfkl.UpSampling2D(size=(2,2), interpolation = 'nearest')(dec)
dec = tfkl.Conv2D(128, kernel_size=(4,4), strides=1, padding='SAME', name='CONV14')(dec)
#dec = tfkl.Conv2DTranspose(64, kernel_size=(4,4), strides=2, padding='SAME', name='CONV14')(dec)
dec = tfkl.BatchNormalization(name = 'BATCH14')(dec)
dec = tfkl.ReLU()(dec)
dec = tfkl.Concatenate(axis=-1)([dec, enc_2])

dec = tfkl.UpSampling2D(size=(2,2), interpolation = 'nearest')(dec)
dec = tfkl.Conv2D(64, kernel_size=(4,4), strides=1, padding='SAME', name='CONV15')(dec)
#dec = tfkl.Conv2DTranspose(32, kernel_size=(4,4), strides=2, padding='SAME', name='CONV15')(dec)
dec = tfkl.BatchNormalization(name = 'BATCH15')(dec)
dec = tfkl.ReLU()(dec)
dec = tfkl.Concatenate(axis=-1)([dec, enc_1])

dec = tfkl.UpSampling2D(size=(2,2), interpolation = 'nearest')(dec)
dec = tfkl.Conv2D(1, kernel_size=(4,4), strides=1, padding='SAME', activation='tanh', name='CONV16')(dec)
#dec = tfkl.Conv2DTranspose(1, kernel_size=(4,4), strides=2, padding='SAME', activation='tanh', name='CONV16')(dec)

err = MSE()([dec,mask])
#err = MSE()([dec,spec_y])
modelo = tf.keras.Model(inputs=[audio_in, mask_in],outputs=[err])
modelo.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Entrada_audio (InputLayer)      [(None, 257, 256)]   0
# __________________________________________________________________________________________________
# tf_op_layer_expand_audio (Tenso [(None, 257, 256, 1) 0           Entrada_audio[0][0]
# __________________________________________________________________________________________________
# Crop_audio (Cropping2D)         (None, 256, 256, 1)  0           tf_op_layer_expand_audio[0][0]
# __________________________________________________________________________________________________
# CONV1 (Conv2D)                  (None, 128, 128, 64) 1088        Crop_audio[0][0]
# __________________________________________________________________________________________________
# ACT1 (LeakyReLU)                (None, 128, 128, 64) 0           CONV1[0][0]
# __________________________________________________________________________________________________
# CONV2 (Conv2D)                  (None, 64, 64, 128)  131200      ACT1[0][0]
# __________________________________________________________________________________________________
# BATCH2 (BatchNormalization)     (None, 64, 64, 128)  512         CONV2[0][0]
# __________________________________________________________________________________________________
# ACT2 (LeakyReLU)                (None, 64, 64, 128)  0           BATCH2[0][0]
# __________________________________________________________________________________________________
# CONV3 (Conv2D)                  (None, 32, 32, 256)  524544      ACT2[0][0]
# __________________________________________________________________________________________________
# BATCH3 (BatchNormalization)     (None, 32, 32, 256)  1024        CONV3[0][0]
# __________________________________________________________________________________________________
# ACT3 (LeakyReLU)                (None, 32, 32, 256)  0           BATCH3[0][0]
# __________________________________________________________________________________________________
# CONV4 (Conv2D)                  (None, 16, 16, 512)  2097664     ACT3[0][0]
# __________________________________________________________________________________________________
# BATCH4 (BatchNormalization)     (None, 16, 16, 512)  2048        CONV4[0][0]
# __________________________________________________________________________________________________
# ACT4 (LeakyReLU)                (None, 16, 16, 512)  0           BATCH4[0][0]
# __________________________________________________________________________________________________
# CONV5 (Conv2D)                  (None, 8, 8, 512)    4194816     ACT4[0][0]
# __________________________________________________________________________________________________
# BATCH5 (BatchNormalization)     (None, 8, 8, 512)    2048        CONV5[0][0]
# __________________________________________________________________________________________________
# ACT5 (LeakyReLU)                (None, 8, 8, 512)    0           BATCH5[0][0]
# __________________________________________________________________________________________________
# CONV6 (Conv2D)                  (None, 4, 4, 512)    4194816     ACT5[0][0]
# __________________________________________________________________________________________________
# BATCH6 (BatchNormalization)     (None, 4, 4, 512)    2048        CONV6[0][0]
# __________________________________________________________________________________________________
# ACT6 (LeakyReLU)                (None, 4, 4, 512)    0           BATCH6[0][0]
# __________________________________________________________________________________________________
# CONV7 (Conv2D)                  (None, 2, 2, 512)    4194816     ACT6[0][0]
# __________________________________________________________________________________________________
# BATCH7 (BatchNormalization)     (None, 2, 2, 512)    2048        CONV7[0][0]
# __________________________________________________________________________________________________
# ACT7 (LeakyReLU)                (None, 2, 2, 512)    0           BATCH7[0][0]
# __________________________________________________________________________________________________
# CONV8 (Conv2D)                  (None, 1, 1, 512)    4194816     ACT7[0][0]
# __________________________________________________________________________________________________
# BATCH8 (BatchNormalization)     (None, 1, 1, 512)    2048        CONV8[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 1, 1, 512)    0           BATCH8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 2, 2, 512)    0           re_lu[0][0]
# __________________________________________________________________________________________________
# CONV9 (Conv2D)                  (None, 2, 2, 512)    4194816     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# BATCH9 (BatchNormalization)     (None, 2, 2, 512)    2048        CONV9[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2, 2, 512)    0           BATCH9[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 2, 2, 512)    0           dropout[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           re_lu_1[0][0]
#                                                                  ACT7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 4, 4, 1024)   0           concatenate[0][0]
# __________________________________________________________________________________________________
# CONV10 (Conv2D)                 (None, 4, 4, 512)    8389120     up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# BATCH10 (BatchNormalization)    (None, 4, 4, 512)    2048        CONV10[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 4, 4, 512)    0           BATCH10[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 4, 4, 512)    0           dropout_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           re_lu_2[0][0]
#                                                                  ACT6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 8, 8, 1024)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# CONV11 (Conv2D)                 (None, 8, 8, 512)    8389120     up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# BATCH11 (BatchNormalization)    (None, 8, 8, 512)    2048        CONV11[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 8, 512)    0           BATCH11[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 8, 8, 512)    0           dropout_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           re_lu_3[0][0]
#                                                                  ACT5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 16, 16, 1024) 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# CONV12 (Conv2D)                 (None, 16, 16, 512)  8389120     up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# BATCH12 (BatchNormalization)    (None, 16, 16, 512)  2048        CONV12[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 16, 16, 512)  0           BATCH12[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           re_lu_4[0][0]
#                                                                  ACT4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 32, 32, 1024) 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# CONV13 (Conv2D)                 (None, 32, 32, 256)  4194560     up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# BATCH13 (BatchNormalization)    (None, 32, 32, 256)  1024        CONV13[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 32, 32, 256)  0           BATCH13[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           re_lu_5[0][0]
#                                                                  ACT3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 64, 64, 512)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# CONV14 (Conv2D)                 (None, 64, 64, 128)  1048704     up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# BATCH14 (BatchNormalization)    (None, 64, 64, 128)  512         CONV14[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 64, 64, 128)  0           BATCH14[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           re_lu_6[0][0]
#                                                                  ACT2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 128, 128, 256 0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# CONV15 (Conv2D)                 (None, 128, 128, 64) 262208      up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# BATCH15 (BatchNormalization)    (None, 128, 128, 64) 256         CONV15[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 128, 128, 64) 0           BATCH15[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           re_lu_7[0][0]
#                                                                  ACT1[0][0]
# __________________________________________________________________________________________________
# Entrada_mascara (InputLayer)    [(None, 257, 256)]   0
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 256, 256, 128 0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_expand_mask (Tensor [(None, 257, 256, 1) 0           Entrada_mascara[0][0]
# __________________________________________________________________________________________________
# CONV16 (Conv2D)                 (None, 256, 256, 1)  2049        up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# Crop_mask (Cropping2D)          (None, 256, 256, 1)  0           tf_op_layer_expand_mask[0][0]
# __________________________________________________________________________________________________
# mse (MSE)                       (None, 256, 256, 1)  0           CONV16[0][0]
#                                                                  Crop_mask[0][0]
# ==================================================================================================
# Total params: 54,425,217
# Trainable params: 54,414,337
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %%
#from model.network_architecture import mean_loss
def mean_loss(y_true, y_pred):
    """
    Custom loss. El error cuadratico ya se calcula en la net, solo lo reduzco a un escalar
    """
    return tf.reduce_mean(y_pred)

#Compilacion
modelo.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),loss=mean_loss) #defino el optimizador y le indico que use la loss que defini

#Callbacks
cbks = [tf.keras.callbacks.EarlyStopping(monitor='loss',restore_best_weights=True),
        tf.keras.callbacks.ModelCheckpoint('/content/drive/My Drive/Tesis/scripts/model/ckpts/mascara/sinlog_weights.{epoch:02d}-{loss:.2f}.hdf5'),
        tf.keras.callbacks.TensorBoard(log_dir='tb_logs',profile_batch=0)]

#%load_ext tensorboard
#%tensorboard --logdir tb_logs

# %% [markdown]
# # Entrenamiento

# %%
#modelo.load_weights(MAIN_PATH+'/model/ckpts/mascara/sinlog_weights.05-0.02.hdf5')

# %%
#!ps -aux|grep python
#!kill -9 57 
#!nvidia-smi

# %%
history = modelo.fit_generator(generator=training_generator, validation_data=validation_generator, use_multiprocessing=False, workers=2, epochs=10, callbacks = cbks)
# Out:
# Epoch 1/10
#   2/482 [..............................] - ETA: 3:06 - loss: 0.4902WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2517s vs `on_train_batch_end` time: 0.5271s). Check your callbacks.
# 482/482 [==============================] - 448s 930ms/step - loss: 0.0116 - val_loss: 0.0047
# Epoch 2/10
# 482/482 [==============================] - 463s 960ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 3/10
# 482/482 [==============================] - 450s 934ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 4/10
# 482/482 [==============================] - 451s 936ms/step - loss: 0.0028 - val_loss: 0.0078
# Epoch 5/10
# 482/482 [==============================] - 450s 933ms/step - loss: 0.0026 - val_loss: 0.0033
# Epoch 6/10
# 482/482 [==============================] - 451s 936ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 7/10
# 482/482 [==============================] - 451s 935ms/step - loss: 0.0024 - val_loss: 0.0050
# Epoch 8/10
# 482/482 [==============================] - 451s 936ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 9/10
# 482/482 [==============================] - 450s 933ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 10/10
# 482/482 [==============================] - 459s 952ms/step - loss: 0.0023 - val_loss: 0.0030

# %% [markdown]
# # Resultados

# %%
! ls '{MAIN_PATH+'/data/data_ready_mask'}' | grep 2.npy

# %%
! cp '{MAIN_PATH+'/data/data_ready_mask/3.npy'}' .

# %%
from evaluate import predict_model
[audio, mask] = np.load('3.npy') #tomo un ejemplo del set de entrenamiento por ahora
audio = audio.reshape(1,257,256)
mask= mask.reshape(1,257,256)
activations = predict_model([audio, mask], modelo) #alreves!
#plt.imshow(Spectrogram(512,128,name='STFT_clean')(reverb)[0,:,:], aspect = 'auto')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-37c9c2feebc0> in <module>()
# ----> 1 from evaluate import predict_model
#       2 [audio, mask] = np.load('3.npy') #tomo un ejemplo del set de entrenamiento por ahora
#       3 audio = audio.reshape(1,257,256)
#       4 mask= mask.reshape(1,257,256)
#       5 activations = predict_model([audio, mask], modelo) #alreves!
#
# ModuleNotFoundError: No module named 'evaluate'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
plt.figure(1, figsize=(10,5))
plt.title('Entrada audio')
plt.imshow(activations['Crop_audio'][0,:,:,0], aspect = 'auto')
plt.colorbar()

plt.figure(2, figsize=(10,5))
plt.title('Mascara estimada')
plt.imshow(activations['CONV16'][0,:,:,0], aspect = 'auto')
plt.colorbar()


#plt.figure(3, figsize=(10,5))
#plt.title('Salida')
#plt.imshow(activations['SALIDA'][0,:,:,0].T, aspect = 'auto')
#plt.colorbar()

plt.figure(4, figsize=(10,5))
plt.title('Mascara Objetivo')
#plt.imshow(activations['STFT_clean'][0,:,:].T, aspect = 'auto')
plt.imshow(activations['Crop_mask'][0,:,:,0], aspect = 'auto')
plt.colorbar()

plt.figure(5, figsize=(10,5))
plt.title('Error')
plt.imshow(activations['mse'][0,:,:,0], aspect = 'auto')
plt.colorbar()

# %% [markdown]
# # Recuperando Audio

# %%
import librosa as lb
from scipy.signal import stft
#Importo un par de audios 
clean, rev = np.load(MAIN_PATH+'/data/data_ready/4000.npy')
clean = clean[0:32640]
rev = rev[0:32640]


#preparo la stft para meter a la red 
_, _, clean_spec = stft(clean, nperseg = 512, noverlap = 384)
_, _, rev_spec = stft(rev, nperseg = 512, noverlap = 384)

clean_magspec = np.log(abs(clean_spec)+eps)
rev_magspec = np.log(abs(rev_spec)+eps)

factor = np.max(np.abs(rev_magspec))

clean_magspec = clean_magspec/factor
rev_magspec = rev_magspec/factor

rev_magspec.shape
#estimacion por red 
activations = predict_model([rev_magspec.reshape(1,257,256), rev_magspec.reshape(1,257,256)], modelo)

mask = activations['CONV16'].reshape(256,256) #mascara comprimida
#descomprimo 
c = 0.1
k = 10
mask_descomp = (-1/c) * np.log((k - mask) / (k + mask))
mask_descomp = tf.pad(mask_descomp,((0,1),(0,0)), mode = 'CONSTANT', constant_values=np.min(mask_descomp)).numpy()

objetivo = rev_magspec * mask_descomp
objetivo = objetivo * factor
objetivo = np.exp(objetivo)-eps
estim_audio = lb.griffinlim(objetivo, n_iter=2000,hop_length=128, win_length=512, window='hann', center=True)
# Out:
# orden de las entradas: /
#  ['Entrada_audio', 'Entrada_mascara']

# %%
plt.subplot(3,1,1)
plt.plot(rev[:])
plt.title('Audio ruidoso original')

plt.subplot(3,1,2)
plt.plot(clean[:])
plt.title('Audio limpio objetivo')
plt.subplots_adjust(right=4, top=2)

plt.subplot(3,1,3)
plt.plot(estim_audio)
plt.title('Audio dereverb')
plt.subplots_adjust(right=4, top=2)

import IPython
print('Audio con reverb')
IPython.display.display(IPython.display.Audio(data= rev, rate=16000))
print('Audio limpio')
IPython.display.display(IPython.display.Audio(data = clean , rate=16000))
print('Audio dereverberado')
IPython.display.display(IPython.display.Audio(data = estim_audio , rate=16000))
# Out:
# Audio con reverb
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio limpio
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio dereverberado
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Analizando los datos

# %%
samples = glob.glob('/content/drive/My Drive/Tesis/scripts/data/data_ready**/*.npy', recursive = True)
#samples = samples[:200]

# %%
tf.keras.backend.set_floatx('float64')
max = []
min = []
for sample in samples: 
  anec, rev = np.load(sample)
  #magspec_1 = Spectrogram(512, 128)(anec)
  magspec_2 = tf.math.log(Spectrogram(512, 128)(rev))
  max.append(tf.math.reduce_max(magspec_2).numpy())
  min.append(tf.math.reduce_min(magspec_2).numpy())

# %%
np.max(max)
