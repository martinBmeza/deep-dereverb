# %%
import matplotlib.pyplot as plt 
import numpy as np
import glob

# %%
def plot_results(PESOS, TEST):
    
    path = 'valores/'+PESOS+TEST+'*.npy'

    valores = glob.glob(path)
    val_dict = {}
    for val in valores:
        arr = np.load(val)
        label = val.split('/')[-1].split('.')[0]
        val_dict[label] = arr

    plt.figure(1, figsize=(15,5))
    plt.subplot(1, 3, 1)
    plt.hist(val_dict['SDR_reverb'], label = 'SDR_reverb', alpha=0.8 )
    plt.hist(val_dict['SDR_dereverb'], label = 'SDR_dereverb', alpha=0.8 )
    plt.legend()
    print('SDR reverb: {:.2f} \tSDR dereverb: {:.2f}'.format(np.mean(val_dict['SDR_reverb']), np.mean(val_dict['SDR_dereverb'])))

    plt.subplot(1, 3, 2)
    plt.hist(val_dict['SRMR_reverb'], label = 'SRMR_reverb', alpha=0.8 )
    plt.hist(val_dict['SRMR_dereverb'], label = 'SRMR_dereverb', alpha=0.8 )
    plt.legend()
    print('SRMR reverb: {:.2f} \tSRMR dereverb: {:.2f}'.format(np.mean(val_dict['SRMR_reverb']), np.mean(val_dict['SRMR_dereverb'])))

    plt.subplot(1, 3, 3)
    plt.hist(val_dict['ESTOI_reverb'], label = 'ESTOI_reverb', alpha=0.8 )
    plt.hist(val_dict['ESTOI_dereverb'], label = 'ESTOI_dereverb', alpha=0.8 )
    plt.legend()
    print('ESTOI reverb: {:.2f} \tESTOI dereverb: {:.2f}'.format(np.median(val_dict['ESTOI_reverb']), np.median(val_dict['ESTOI_dereverb'])))

    plt.show()

# %% [markdown]
# # Entrenado con reverb reales

# %%
PESOS = 'pesos_reales/'
TEST = 'real/'
print('Testeado en reverb reales')
plot_results(PESOS, TEST)
# Out:
# Testeado en reverb reales
# SDR reverb: -3.06 	SDR dereverb: -3.84
# SRMR reverb: 1.86 	SRMR dereverb: 6.74
# ESTOI reverb: 0.27 	ESTOI dereverb: 0.62

# %%
print('Testeado en reverb generadas')
TEST = 'gen/'
plot_results(PESOS, TEST)
# Out:
# Testeado en reverb generadas
# SDR reverb: 1.95 	SDR dereverb: -2.81
# SRMR reverb: 3.47 	SRMR dereverb: 6.19
# ESTOI reverb: 0.44 	ESTOI dereverb: 0.59

# %%
print('Testeado en reverb aumentadas')
TEST = 'aug/'
plot_results(PESOS, TEST)
# Out:
# Testeado en reverb aumentadas
# SDR reverb: 9.27 	SDR dereverb: -1.85
# SRMR reverb: 5.64 	SRMR dereverb: 7.97
# ESTOI reverb: 0.68 	ESTOI dereverb: 0.75

# %% [markdown]
# # Entrenado con reverb aumentadas

# %%
PESOS = 'pesos_aug/'
TEST = 'real/'
print('Testeado en reverb reales')
plot_results(PESOS, TEST)
# Out:
# Testeado en reverb reales
# SDR reverb: -3.06 	SDR dereverb: -5.16
# SRMR reverb: 1.86 	SRMR dereverb: 4.73
# ESTOI reverb: 0.28 	ESTOI dereverb: 0.45

# %%
print('Testeado en reverb generadas')
TEST = 'gen/'
plot_results(PESOS, TEST)
# Out:
# Testeado en reverb generadas
# SDR reverb: 1.95 	SDR dereverb: -2.86
# SRMR reverb: 3.47 	SRMR dereverb: 5.93
# ESTOI reverb: 0.44 	ESTOI dereverb: 0.56

# %%
print('Testeado en reverb aumentadas')
TEST = 'aug/'
plot_results(PESOS, TEST)
# Out:
# Testeado en reverb aumentadas
# SDR reverb: 9.27 	SDR dereverb: -1.62
# SRMR reverb: 5.64 	SRMR dereverb: 7.85
# ESTOI reverb: 0.68 	ESTOI dereverb: 0.77

# %% [markdown]
# # Entrenado con reverb sinteticas

# %%
PESOS = 'pesos_gen/'
TEST = 'real/'
print('Testeado en reverb reales')
plot_results(PESOS, TEST)
# Out:
# Testeado en reverb reales
# SDR reverb: -3.06 	SDR dereverb: -6.33
# SRMR reverb: 1.86 	SRMR dereverb: 3.71
# ESTOI reverb: 0.28 	ESTOI dereverb: 0.43

# %%
print('Testeado en reverb generadas')
TEST = 'gen/'
plot_results(PESOS, TEST)
# Out:
# Testeado en reverb generadas
# SDR reverb: 1.95 	SDR dereverb: -2.85
# SRMR reverb: 3.47 	SRMR dereverb: 6.55
# ESTOI reverb: 0.44 	ESTOI dereverb: 0.67

# %%
print('Testeado en reverb aumentadas')
TEST = 'aug/'
plot_results(PESOS, TEST)
# Out:
# Testeado en reverb aumentadas
# SDR reverb: 9.27 	SDR dereverb: -2.51
# SRMR reverb: 5.64 	SRMR dereverb: 7.94
# ESTOI reverb: 0.68 	ESTOI dereverb: 0.75
